# %%
import json

path = 'out/dataset/Definite MG/00-00.json'

data = json.load(open(path))
print(data["visits"]["0"]['freq_1.0'].keys())
# Out:
# dict_keys(['velocity_horizontalLH', 'velocity_horizontalRH', 'velocity_horizontalAVG', 'speed_horizontalLH', 'speed_horizontalRH', 'speed_horizontalAVG', 'gain_horizontalLH', 'gain_horizontalRH', 'gain_horizontalAVG', 'velocity_verticalLV', 'velocity_verticalRV', 'velocity_verticalAVG', 'speed_verticalLV', 'speed_verticalRV', 'speed_verticalAVG', 'gain_verticalLV', 'gain_verticalRV', 'gain_verticalAVG'])
