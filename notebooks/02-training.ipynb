# %%
import os
import random
import json
from functools import partial

import torch
import torch.nn as nn

from torch.utils.data import DataLoader
from torch.optim import Adam
import numpy as np
import json
from models.accession_dataset import AccessionDataset, ocular_collate_fn
from models.lstm import OcularStatefulLSTM

SELECTED_FREQUENCY = '1.0'
DATASET_PATH = '../exports/dataset/v2'
RESULTS_DIR = 'out'

SAMPLING_RATE = 240

FREQUENCIES_WINDOWS = {
    "0.5": int(SAMPLING_RATE * 2),
    "0.75": int(SAMPLING_RATE * 1.5),
    "1.0": int(SAMPLING_RATE * 1.0),
}

window_size = FREQUENCIES_WINDOWS[SELECTED_FREQUENCY]

# %%
mg_samples = os.listdir(os.path.join(DATASET_PATH, "Definite MG"))
healthy_samples = os.listdir(os.path.join(DATASET_PATH, "Healthy control"))

print("MG len", len(mg_samples))
print("Healthy len", len(healthy_samples))
# Out:
# MG len 64
# Healthy len 86

# %% [markdown]
# ## 5-fold cross validation
# We are generating crosss validation to check the performance of our model because dataset is short

# %%
seed = 42
random.seed(seed)

n_folds = 5

healthy_shuffled = healthy_samples.copy()
mg_shuffled = mg_samples.copy()

random.shuffle(healthy_shuffled)
random.shuffle(mg_shuffled)

folds = []
for fold_idx in range(n_folds):
    val_healthy = healthy_shuffled[fold_idx::n_folds]
    train_healthy = [s for i, s in enumerate(healthy_shuffled) if i % n_folds != fold_idx]

    val_mg = mg_shuffled[fold_idx::n_folds]
    train_mg = [s for i, s in enumerate(mg_shuffled) if i % n_folds != fold_idx]

    folds.append({
        "fold": fold_idx,
        "train": {
            "healthy": train_healthy,
            "mg": train_mg,
        },
        "val": {
            "healthy": val_healthy,
            "mg": val_mg,
        },
    })

config = {
    "seed": seed,
    "n_folds": n_folds,
    "dataset_path": DATASET_PATH,
    "folds": folds,
}

with open(os.path.join(RESULTS_DIR, "cv_config.json"), "w") as f:
    json.dump(config, f, indent=2)

print("Configuration of 5-fold saved in cv_config.json")
# Out:
# Configuration of 5-fold saved in cv_config.json

# %%
def run_epoch(model, loader, optimizer, criterion, device, is_train=True):
    if is_train:
        model.train()
        torch.set_grad_enabled(True)
    else:
        model.eval()
        torch.set_grad_enabled(False)
        
    total_loss = 0.0
    correct = 0
    total = 0
    
    for sequences, labels, masks in loader:
        sequences = sequences.to(device)
        labels = labels.to(device).long()
        masks = masks.to(device)
        
        outputs = model(sequences, masks)
        loss = criterion(outputs, labels)
        
        if is_train:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
        total_loss += loss.item() * labels.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    return total_loss / total, 100 * correct / total

# %%
def train_with_json_splits(splits_json_path, base_dataset_dir, epochs=15, batch_size=1):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    # Load your custom split configurations
    with open(splits_json_path, 'r') as f:
        config = json.load(f)
        
    folds_config = config.get('folds', [])
    print(f"Loaded config containing {len(folds_config)} pre-configured folds.")

    fold_train_accs, fold_val_accs = [], []

    # Iterate through each predefined fold in the JSON
    for fold_data in folds_config:
        fold_idx = fold_data['fold']
        print(f"\n" + "="*50)
        print(f" TRAINING PREDEFINED FOLD {fold_idx + 1}/{len(folds_config)} ")
        print("="*50)

        # Helper function to construct absolute/relative paths from raw filenames
        def resolve_paths(split_section):
            paths = []
            # Check Healthy files under 'Healthy control' folder
            for f_name in split_section.get('healthy', []):
                paths.append(os.path.join(base_dataset_dir, 'Healthy control', f_name))
            # Check MG files under 'Definite MG' and 'Probable MG' subfolders
            for f_name in split_section.get('mg', []):
                definite_path = os.path.join(base_dataset_dir, 'Definite MG', f_name)
                probable_path = os.path.join(base_dataset_dir, 'Probable MG', f_name)
                if os.path.exists(definite_path):
                    paths.append(definite_path)
                elif os.path.exists(probable_path):
                    paths.append(probable_path)
                else:
                    # Fallback if your export directory tree doesn't use subfolders
                    paths.append(os.path.join(base_dataset_dir, f_name))
            return paths

        # Resolve complete file structures for this split
        train_paths = resolve_paths(fold_data['train'])
        val_paths = resolve_paths(fold_data['val'])

        # Initialize PyTorch Datasets using all three available frequency windows
        train_dataset = AccessionDataset(train_paths, window_size=window_size, frequency_key='all')
        val_dataset = AccessionDataset(val_paths, window_size=window_size, frequency_key='all')

        num_features = train_dataset[0][0].shape[1] if len(train_dataset) > 0 else 24
        print(f"Model input feature size: {num_features}")

        # Build active DataLoaders using your customized collate mechanism
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=ocular_collate_fn)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=ocular_collate_fn)

        # Initialize fresh binary classification model parameters with data-driven feature dimensions
        model = OcularStatefulLSTM(input_size=num_features, num_classes=2).to(device)
        criterion = nn.CrossEntropyLoss()
        # optimizer = Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
        optimizer = Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

        best_val_acc = 0.0

        for epoch in range(epochs):
            train_loss, train_acc = run_epoch(model, train_loader, optimizer, criterion, device, is_train=True)
            val_loss, val_acc = run_epoch(model, val_loader, None, criterion, device, is_train=False)
            
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                
            print(f"Epoch [{epoch+1}/{epochs}] | Train Loss: {train_loss:.4f} Acc: {train_acc:.2f}% | Val Loss: {val_loss:.4f} Acc: {val_acc:.2f}%")

        print(f">> Fold {fold_idx + 1} Done. Best Validation Accuracy: {best_val_acc:.2f}%")
        fold_val_accs.append(best_val_acc)
        fold_train_accs.append(train_acc)

    print("\n" + "═"*50)
    print(" FINAL PREDEFINED CROSS VALIDATION METRICS SUMMARY")
    print("═"*50)
    print(f"Mean Training Accuracy: {np.mean(fold_train_accs):.2f}%")
    print(f"Mean Validation Accuracy: {np.mean(fold_val_accs):.2f}% (+/- {np.std(fold_val_accs):.2f}%)")

# %%
# Debug helper: muestra qué archivos/visitas no contienen todas las frecuencias requeridas
REQUIRED_FREQS = ['freq_0.5', 'freq_0.75', 'freq_1.0']
missing_samples = []

for label in ['Definite MG', 'Healthy control']:
    folder = os.path.join(DATASET_PATH, label)
    for filename in sorted(os.listdir(folder)):
        path = os.path.join(folder, filename)
        try:
            with open(path, 'r', encoding='utf-8') as f:
                data = json.load(f)
        except Exception as e:
            print(f'ERROR reading {path}: {e}')
            continue

        visits = data.get('visits', {})
        for visit_id, visit_data in visits.items():
            if not isinstance(visit_data, dict):
                continue
            missing = [freq for freq in REQUIRED_FREQS if freq not in visit_data]
            if missing:
                missing_samples.append((label, filename, visit_id, missing))

print(f'Total visits with missing frequencies: {len(missing_samples)}')
for label, filename, visit_id, missing in missing_samples[:50]:
    print(f'{label}/{filename} visit={visit_id} missing={missing}')
# Out:
# Total visits with missing frequencies: 0

# %%
# Set paths pointing to your local assets
SPLITS_JSON = os.path.join(RESULTS_DIR, "cv_config.json")          # Path to your split manifest json

train_with_json_splits(SPLITS_JSON, DATASET_PATH, epochs=15, batch_size=8)
# Out:
# Using device: cuda
# Loaded config containing 5 pre-configured folds.
#
# ==================================================
#  TRAINING PREDEFINED FOLD 1/5
# ==================================================
# Model input feature size: 24
# Epoch [1/15] | Train Loss: 0.6867 Acc: 62.90% | Val Loss: 0.6922 Acc: 54.55%
# Epoch [2/15] | Train Loss: 0.6908 Acc: 53.23% | Val Loss: 0.6931 Acc: 54.55%
# Epoch [3/15] | Train Loss: 0.6712 Acc: 60.48% | Val Loss: 0.6886 Acc: 54.55%
# Epoch [4/15] | Train Loss: 0.6532 Acc: 64.52% | Val Loss: 0.6788 Acc: 60.61%
# Epoch [5/15] | Train Loss: 0.6482 Acc: 62.90% | Val Loss: 0.6888 Acc: 60.61%
# Epoch [6/15] | Train Loss: 0.6536 Acc: 59.68% | Val Loss: 0.7061 Acc: 54.55%
# Epoch [7/15] | Train Loss: 0.6727 Acc: 52.42% | Val Loss: 0.6511 Acc: 66.67%
# Epoch [8/15] | Train Loss: 0.6416 Acc: 66.13% | Val Loss: 0.6791 Acc: 54.55%
# Epoch [9/15] | Train Loss: 0.6115 Acc: 72.58% | Val Loss: 0.6649 Acc: 63.64%
# Epoch [10/15] | Train Loss: 0.6151 Acc: 64.52% | Val Loss: 0.6623 Acc: 63.64%
# Epoch [11/15] | Train Loss: 0.5809 Acc: 68.55% | Val Loss: 0.7020 Acc: 63.64%
# Epoch [12/15] | Train Loss: 0.6649 Acc: 61.29% | Val Loss: 0.7119 Acc: 60.61%
# Epoch [13/15] | Train Loss: 0.6050 Acc: 68.55% | Val Loss: 0.6248 Acc: 72.73%
# Epoch [14/15] | Train Loss: 0.6066 Acc: 65.32% | Val Loss: 0.6333 Acc: 66.67%
# Epoch [15/15] | Train Loss: 0.6032 Acc: 71.77% | Val Loss: 0.6092 Acc: 63.64%
# >> Fold 1 Done. Best Validation Accuracy: 72.73%
#
# ==================================================
#  TRAINING PREDEFINED FOLD 2/5
# ==================================================
# Model input feature size: 24
# Epoch [1/15] | Train Loss: 0.7058 Acc: 42.86% | Val Loss: 0.7072 Acc: 38.71%
# Epoch [2/15] | Train Loss: 0.6838 Acc: 54.76% | Val Loss: 0.7082 Acc: 51.61%
# Epoch [3/15] | Train Loss: 0.6767 Acc: 61.11% | Val Loss: 0.7167 Acc: 45.16%
# Epoch [4/15] | Train Loss: 0.6690 Acc: 59.52% | Val Loss: 0.7103 Acc: 45.16%
# Epoch [5/15] | Train Loss: 0.6652 Acc: 61.11% | Val Loss: 0.6867 Acc: 54.84%
# Epoch [6/15] | Train Loss: 0.6495 Acc: 62.70% | Val Loss: 0.7141 Acc: 41.94%
# Epoch [7/15] | Train Loss: 0.6357 Acc: 65.08% | Val Loss: 0.7089 Acc: 41.94%
# Epoch [8/15] | Train Loss: 0.6536 Acc: 57.94% | Val Loss: 0.7635 Acc: 41.94%
# Epoch [9/15] | Train Loss: 0.6358 Acc: 65.08% | Val Loss: 0.6760 Acc: 58.06%
# Epoch [10/15] | Train Loss: 0.6556 Acc: 60.32% | Val Loss: 0.6958 Acc: 48.39%
# Epoch [11/15] | Train Loss: 0.6207 Acc: 67.46% | Val Loss: 0.7269 Acc: 48.39%
# Epoch [12/15] | Train Loss: 0.6312 Acc: 63.49% | Val Loss: 0.7871 Acc: 48.39%
# Epoch [13/15] | Train Loss: 0.6152 Acc: 71.43% | Val Loss: 0.8136 Acc: 51.61%
# Epoch [14/15] | Train Loss: 0.5857 Acc: 75.40% | Val Loss: 0.8935 Acc: 41.94%
# Epoch [15/15] | Train Loss: 0.6069 Acc: 68.25% | Val Loss: 0.8936 Acc: 38.71%
# >> Fold 2 Done. Best Validation Accuracy: 58.06%
#
# ==================================================
#  TRAINING PREDEFINED FOLD 3/5
# ==================================================
# Model input feature size: 24
# Epoch [1/15] | Train Loss: 0.7047 Acc: 47.62% | Val Loss: 0.6813 Acc: 67.74%
# Epoch [2/15] | Train Loss: 0.6876 Acc: 50.79% | Val Loss: 0.6765 Acc: 54.84%
# Epoch [3/15] | Train Loss: 0.6892 Acc: 54.76% | Val Loss: 0.6793 Acc: 61.29%
# Epoch [4/15] | Train Loss: 0.6833 Acc: 53.97% | Val Loss: 0.6828 Acc: 58.06%
# Epoch [5/15] | Train Loss: 0.6671 Acc: 63.49% | Val Loss: 0.6741 Acc: 61.29%
# Epoch [6/15] | Train Loss: 0.6736 Acc: 59.52% | Val Loss: 0.6806 Acc: 54.84%
# Epoch [7/15] | Train Loss: 0.6643 Acc: 64.29% | Val Loss: 0.6820 Acc: 54.84%
# Epoch [8/15] | Train Loss: 0.6614 Acc: 60.32% | Val Loss: 0.6913 Acc: 48.39%
# Epoch [9/15] | Train Loss: 0.6565 Acc: 60.32% | Val Loss: 0.6976 Acc: 54.84%
# Epoch [10/15] | Train Loss: 0.6324 Acc: 66.67% | Val Loss: 0.7349 Acc: 45.16%
# Epoch [11/15] | Train Loss: 0.6379 Acc: 65.08% | Val Loss: 0.7525 Acc: 41.94%
# Epoch [12/15] | Train Loss: 0.6471 Acc: 62.70% | Val Loss: 0.6700 Acc: 54.84%
# Epoch [13/15] | Train Loss: 0.6446 Acc: 66.67% | Val Loss: 0.6926 Acc: 58.06%
# Epoch [14/15] | Train Loss: 0.6147 Acc: 66.67% | Val Loss: 0.7350 Acc: 54.84%
# Epoch [15/15] | Train Loss: 0.6027 Acc: 68.25% | Val Loss: 0.8780 Acc: 48.39%
# >> Fold 3 Done. Best Validation Accuracy: 67.74%
#
# ==================================================
#  TRAINING PREDEFINED FOLD 4/5
# ==================================================
# Model input feature size: 24
# Epoch [1/15] | Train Loss: 0.6996 Acc: 49.21% | Val Loss: 0.6945 Acc: 54.84%
# Epoch [2/15] | Train Loss: 0.6808 Acc: 57.94% | Val Loss: 0.6898 Acc: 45.16%
# Epoch [3/15] | Train Loss: 0.6670 Acc: 61.90% | Val Loss: 0.6973 Acc: 51.61%
# Epoch [4/15] | Train Loss: 0.6650 Acc: 62.70% | Val Loss: 0.7098 Acc: 35.48%
# Epoch [5/15] | Train Loss: 0.6649 Acc: 62.70% | Val Loss: 0.7046 Acc: 41.94%
# Epoch [6/15] | Train Loss: 0.6333 Acc: 67.46% | Val Loss: 0.7165 Acc: 51.61%
# Epoch [7/15] | Train Loss: 0.6391 Acc: 63.49% | Val Loss: 0.7385 Acc: 41.94%
# Epoch [8/15] | Train Loss: 0.5941 Acc: 69.84% | Val Loss: 0.7757 Acc: 54.84%
# Epoch [9/15] | Train Loss: 0.6541 Acc: 67.46% | Val Loss: 0.7906 Acc: 45.16%
# Epoch [10/15] | Train Loss: 0.6196 Acc: 64.29% | Val Loss: 0.7485 Acc: 48.39%
